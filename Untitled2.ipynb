# %% [markdown]
# <a href="https://colab.research.google.com/github/wyueidkmn/TKU-AI-412630542/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
# !pip install pytesseract
# !pip install imutils

# %%
import cv2
import imutils
import pytesseract
from google.colab import files

def recognize_license_plate(image_path):
    # 讀取圖像
    image = cv2.imread(image_path)

    # 對圖像進行預處理
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.bilateralFilter(gray, 11, 17, 17)
    edged = cv2.Canny(gray, 30, 200)

    # 尋找輪廓
    contours = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

    # 初始化車牌位置
    license_plate = None

    # 遍歷輪廓，找到可能的車牌
    for contour in contours:
        perimeter = cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, 0.018 * perimeter, True)
        if len(approx) == 4:
            license_plate = approx
            break

    # 如果找到車牌，進行辨識
    if license_plate is not None:
        mask = np.zeros(gray.shape, np.uint8)
        new_image = cv2.drawContours(mask, [license_plate], 0, 255, -1)
        new_image = cv2.bitwise_and(image, image, mask=mask)

        # 進行OCR辨識
        configuration = r'--oem 3 --psm 7'
        text = pytesseract.image_to_string(new_image, config=configuration)

        # 顯示結果
        print("辨識結果：", text)
    else:
        print("找不到車牌")

# 上傳圖片
uploaded = files.upload()

# 取得上傳圖片的檔案名稱
image_path = list(uploaded.keys())[0]

# 辨識車牌
recognize_license_plate(image_path)
# Out:
#      <input type="file" id="files-765391fb-ce1f-4124-a8fd-c6830deba661" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-765391fb-ce1f-4124-a8fd-c6830deba661">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
